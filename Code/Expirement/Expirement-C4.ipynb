# %% [markdown]
# # 18COC102 -  Advanced Artificial Intelligence Systems - Coursework

# %% [markdown]
# <hr>
# <p style='color:red'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Experiment C4</p>
# <hr>

# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -p numpy,torch,torchvision
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.6.7
# IPython 7.2.0
#
# numpy 1.15.4
# torch 0.4.1
# torchvision 0.2.1

# %%
# import all dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import time
import os
from tensorboardX import SummaryWriter

# %%
# some of line are refer source[1]
# network (VGG16) : this network reduce some convolution cores in oder to improve speed
class VGG16(nn.Module):
    
    def __init__(self):
        
        super(VGG16,self).__init__()
        self.conv1 = nn.Conv2d(3,64,3,padding=1)
        self.conv2 = nn.Conv2d(64,64,3,padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu1 = nn.ReLU()

        self.conv3 = nn.Conv2d(64,128,3,padding=1)
        self.conv4 = nn.Conv2d(128, 128, 3,padding=1)
        self.pool2 = nn.MaxPool2d(2, 2, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.relu2 = nn.ReLU()

        self.conv5 = nn.Conv2d(128,128, 3,padding=1)
        self.conv6 = nn.Conv2d(128, 128, 3,padding=1)
        self.conv7 = nn.Conv2d(128, 128, 1,padding=1)
        self.pool3 = nn.MaxPool2d(2, 2, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.relu3 = nn.ReLU()

        self.conv8 = nn.Conv2d(128, 256, 3,padding=1)
        self.conv9 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv10 = nn.Conv2d(256, 256, 1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.relu4 = nn.ReLU()

        self.conv11 = nn.Conv2d(256, 512, 3, padding=1)
        self.conv12 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv13 = nn.Conv2d(512, 512, 1, padding=1)
        self.pool5 = nn.MaxPool2d(2, 2, padding=1)
        self.bn5 = nn.BatchNorm2d(512)
        self.relu5 = nn.ReLU()

        self.fc14 = nn.Linear(512*4*4,1024)
        self.drop1 = nn.Dropout2d()
        self.fc15 = nn.Linear(1024,1024)
        self.drop2 = nn.Dropout2d()
        self.fc16 = nn.Linear(1024,10)
        
    def forward(self,x):
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.pool1(x)
        x = self.bn1(x)
        x = self.relu1(x)


        x = self.conv3(x)
        x = self.conv4(x)
        x = self.pool2(x)
        x = self.bn2(x)
        x = self.relu2(x)

        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.pool3(x)
        x = self.bn3(x)
        x = self.relu3(x)

        x = self.conv8(x)
        x = self.conv9(x)
        x = self.conv10(x)
        x = self.pool4(x)
        x = self.bn4(x)
        x = self.relu4(x)

        x = self.conv11(x)
        x = self.conv12(x)
        x = self.conv13(x)
        x = self.pool5(x)
        x = self.bn5(x)
        x = self.relu5(x)

        x = x.view(-1,512*4*4)
        x = F.relu(self.fc14(x))
        x = self.drop1(x)
        x = F.relu(self.fc15(x))
        x = self.drop2(x)
        x = self.fc16(x)

        return x

#end of source [1]
#source [1] https://juejin.im/entry/5bf51d35e51d454049668d57

# %%
# parameters
learning_rate=0.001
batch_size=200
epoch=200
workers=2

# %%
# set GPU 
device = torch.device("cuda:0")
# set Netwrok
net = VGG16()
net = net.to(device)
# set optimizer
optimizer = optim.RMSprop(net.parameters(), lr=learning_rate)
# set loss function
loss = nn.CrossEntropyLoss()

# %%
# dataloader refer source [2]

# load training dataset
trainingset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, 
                                           transform=transforms.ToTensor())

trainingloader = torch.utils.data.DataLoader(trainingset, batch_size=batch_size,shuffle=True, 
                                             num_workers=workers)
# load testing dataset
testingset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transforms.ToTensor())

testingloader = torch.utils.data.DataLoader(testingset, batch_size=batch_size,
                                         shuffle=False, num_workers=workers)

#end of source [2]
#source [2] https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#ALL THE CODE IN THIS CELL ARE WRITE BY MY SELF#
# Start training : set net to train model
net.train()

# make two arrays for saving matplotlib data
train_loss = []
train_accu = []
accuracy = 0

# get TersorBoard writer object
writer = SummaryWriter(log_dir='Training')

# Training process
timestart = time.time()
for epoch in range(0,epoch):
    
    # initialize loss,total,correct
    loss_value = 0.0
    total = 0
    correct = 0
    accuracy = 0
    
    # do iteration (total number of training images / batch size) times
    for i, (inputs, labels) in enumerate(trainingloader, 0):
        
        # get the input and its label
        inputs = inputs.to(device)
        labels = labels.to(device)

        # make gradients to 0
        optimizer.zero_grad()

        # forward step
        outputs = net(inputs)
        
        # compute the loss
        l = loss(outputs, labels)
        
        # backward step
        l.backward()
        
        # optimize step
        optimizer.step()

        # compute loss
        loss_value += l.item()
        
        # save to array in oder to output loss image at the end
        train_loss.append(l.item())
        
        # write to tensorboard file
        writer.add_scalars('/GroupC/Loss', {'C4': l.item()}, epoch)

        
        # compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total = total + labels.size(0)
        correct = correct + (predicted == labels).sum().item()
        accuracy = correct / total * 100.0
        
        # save to array in oder to output accuracy image at the end
        train_accu.append(accuracy)
        
        # write to tensorboard file
        writer.add_scalars('/GroupC/Accuracy', {'C4': accuracy}, epoch)
        

    loss_epoch = loss_value / (500000/batch_size)
    # output the result of this epoch 
    print('[epoch %d]  Loss: %.4f  Accuracy: %.3f %%' %(epoch, loss_epoch , accuracy))

    
# Finish Training
result_training_accuracy = accuracy
result_training_time = (time.time()-timestart)
print('Finished Training! Training process cost %3f sec' %result_training_time)
# Out:
# [epoch 0]  Loss: 0.2414  Accuracy: 14.990 %
# [epoch 1]  Loss: 0.2018  Accuracy: 17.000 %
# [epoch 2]  Loss: 0.1886  Accuracy: 20.392 %
# [epoch 3]  Loss: 0.1804  Accuracy: 25.964 %
# [epoch 4]  Loss: 0.1640  Accuracy: 32.728 %
# [epoch 5]  Loss: 0.1512  Accuracy: 38.156 %
# [epoch 6]  Loss: 0.1420  Accuracy: 42.642 %
# [epoch 7]  Loss: 0.1323  Accuracy: 47.416 %
# [epoch 8]  Loss: 0.1216  Accuracy: 52.614 %
# [epoch 9]  Loss: 0.1105  Accuracy: 58.744 %
# [epoch 10]  Loss: 0.1004  Accuracy: 63.804 %
# [epoch 11]  Loss: 0.0919  Accuracy: 67.374 %
# [epoch 12]  Loss: 0.0857  Accuracy: 69.820 %
# [epoch 13]  Loss: 0.0808  Accuracy: 71.948 %
# [epoch 14]  Loss: 0.0768  Accuracy: 73.326 %
# [epoch 15]  Loss: 0.0727  Accuracy: 74.524 %
# [epoch 16]  Loss: 0.0688  Accuracy: 76.226 %
# [epoch 17]  Loss: 0.0661  Accuracy: 77.074 %
# [epoch 18]  Loss: 0.0628  Accuracy: 78.468 %
# [epoch 19]  Loss: 0.0598  Accuracy: 79.662 %
# [epoch 20]  Loss: 0.0575  Accuracy: 80.358 %
# [epoch 21]  Loss: 0.0550  Accuracy: 81.350 %
# [epoch 22]  Loss: 0.0526  Accuracy: 82.066 %
# [epoch 23]  Loss: 0.0505  Accuracy: 82.792 %
# [epoch 24]  Loss: 0.0485  Accuracy: 83.522 %
# [epoch 25]  Loss: 0.0468  Accuracy: 84.236 %
# [epoch 26]  Loss: 0.0447  Accuracy: 85.048 %
# [epoch 27]  Loss: 0.0427  Accuracy: 85.730 %
# [epoch 28]  Loss: 0.0407  Accuracy: 86.266 %
# [epoch 29]  Loss: 0.0390  Accuracy: 86.834 %
# [epoch 30]  Loss: 0.0377  Accuracy: 87.318 %
# [epoch 31]  Loss: 0.0361  Accuracy: 87.978 %
# [epoch 32]  Loss: 0.0344  Accuracy: 88.566 %
# [epoch 33]  Loss: 0.0331  Accuracy: 88.962 %
# [epoch 34]  Loss: 0.0326  Accuracy: 89.072 %
# [epoch 35]  Loss: 0.0307  Accuracy: 89.788 %
# [epoch 36]  Loss: 0.0405  Accuracy: 87.606 %
# [epoch 37]  Loss: 0.0273  Accuracy: 90.742 %
# [epoch 38]  Loss: 0.0276  Accuracy: 90.738 %
# [epoch 39]  Loss: 0.0270  Accuracy: 91.024 %
# [epoch 40]  Loss: 0.0256  Accuracy: 91.418 %
# [epoch 41]  Loss: 0.0252  Accuracy: 91.714 %
# [epoch 42]  Loss: 0.0240  Accuracy: 92.154 %
# [epoch 43]  Loss: 0.0236  Accuracy: 92.256 %
# [epoch 44]  Loss: 0.0222  Accuracy: 92.702 %
# [epoch 45]  Loss: 0.0218  Accuracy: 92.848 %
# [epoch 46]  Loss: 0.0208  Accuracy: 93.126 %
# [epoch 47]  Loss: 0.0290  Accuracy: 91.222 %
# [epoch 48]  Loss: 0.0176  Accuracy: 94.234 %
# [epoch 49]  Loss: 0.0184  Accuracy: 94.012 %
# [epoch 50]  Loss: 0.0182  Accuracy: 94.078 %
# [epoch 51]  Loss: 0.0175  Accuracy: 94.260 %
# [epoch 52]  Loss: 0.0175  Accuracy: 94.322 %
# [epoch 53]  Loss: 0.0162  Accuracy: 94.716 %
# [epoch 54]  Loss: 0.0161  Accuracy: 94.716 %
# [epoch 55]  Loss: 0.0157  Accuracy: 94.840 %
# [epoch 56]  Loss: 0.0155  Accuracy: 94.980 %
# [epoch 57]  Loss: 0.0148  Accuracy: 95.286 %
# [epoch 58]  Loss: 0.0144  Accuracy: 95.378 %
# [epoch 59]  Loss: 0.0135  Accuracy: 95.630 %
# [epoch 60]  Loss: 0.0134  Accuracy: 95.660 %
# [epoch 61]  Loss: 0.0135  Accuracy: 95.732 %
# [epoch 62]  Loss: 0.0128  Accuracy: 95.948 %
# [epoch 63]  Loss: 0.0119  Accuracy: 96.258 %
# [epoch 64]  Loss: 0.0120  Accuracy: 96.246 %
# [epoch 65]  Loss: 0.0122  Accuracy: 96.178 %
# [epoch 66]  Loss: 0.0119  Accuracy: 96.274 %
# [epoch 67]  Loss: 0.0115  Accuracy: 96.454 %
# [epoch 68]  Loss: 0.0104  Accuracy: 96.744 %
# [epoch 69]  Loss: 0.0107  Accuracy: 96.676 %
# [epoch 70]  Loss: 0.0107  Accuracy: 96.646 %
# [epoch 71]  Loss: 0.0101  Accuracy: 96.856 %
# [epoch 72]  Loss: 0.0100  Accuracy: 96.830 %
# [epoch 73]  Loss: 0.0094  Accuracy: 97.074 %
# [epoch 74]  Loss: 0.0091  Accuracy: 97.176 %
# [epoch 75]  Loss: 0.0102  Accuracy: 96.932 %
# [epoch 76]  Loss: 0.0088  Accuracy: 97.318 %
# [epoch 77]  Loss: 0.0096  Accuracy: 97.054 %
# [epoch 78]  Loss: 0.0095  Accuracy: 97.146 %
# [epoch 79]  Loss: 0.0081  Accuracy: 97.458 %
# [epoch 80]  Loss: 0.0087  Accuracy: 97.338 %
# [epoch 81]  Loss: 0.0081  Accuracy: 97.476 %
# [epoch 82]  Loss: 0.0082  Accuracy: 97.516 %
# [epoch 83]  Loss: 0.0077  Accuracy: 97.582 %
# [epoch 84]  Loss: 0.0073  Accuracy: 97.742 %
# [epoch 85]  Loss: 0.0078  Accuracy: 97.580 %
# [epoch 86]  Loss: 0.0078  Accuracy: 97.564 %
# [epoch 87]  Loss: 0.0079  Accuracy: 97.604 %
# [epoch 88]  Loss: 0.0071  Accuracy: 97.874 %
# [epoch 89]  Loss: 0.0069  Accuracy: 97.762 %
# [epoch 90]  Loss: 0.0073  Accuracy: 97.758 %
# [epoch 91]  Loss: 0.0062  Accuracy: 98.100 %
# [epoch 92]  Loss: 0.0070  Accuracy: 97.818 %
# [epoch 93]  Loss: 0.0066  Accuracy: 98.032 %
# [epoch 94]  Loss: 0.0061  Accuracy: 98.214 %
# [epoch 95]  Loss: 0.0070  Accuracy: 97.858 %
# [epoch 96]  Loss: 0.0150  Accuracy: 96.378 %
# [epoch 97]  Loss: 0.0049  Accuracy: 98.480 %
# [epoch 98]  Loss: 0.0048  Accuracy: 98.540 %
# [epoch 99]  Loss: 0.0063  Accuracy: 98.094 %
# [epoch 100]  Loss: 0.0059  Accuracy: 98.214 %
# [epoch 101]  Loss: 0.0057  Accuracy: 98.162 %
# [epoch 102]  Loss: 0.0061  Accuracy: 98.264 %
# [epoch 103]  Loss: 0.0060  Accuracy: 98.224 %
# [epoch 104]  Loss: 0.0056  Accuracy: 98.272 %
# [epoch 105]  Loss: 0.0060  Accuracy: 98.238 %
# [epoch 106]  Loss: 0.0055  Accuracy: 98.278 %
# [epoch 107]  Loss: 0.0051  Accuracy: 98.420 %
# [epoch 108]  Loss: 0.0060  Accuracy: 98.220 %
# [epoch 109]  Loss: 0.0058  Accuracy: 98.250 %
# [epoch 110]  Loss: 0.0061  Accuracy: 98.218 %
# [epoch 111]  Loss: 0.0053  Accuracy: 98.436 %
# [epoch 112]  Loss: 0.0120  Accuracy: 97.490 %
# [epoch 113]  Loss: 0.0041  Accuracy: 98.768 %
# [epoch 114]  Loss: 0.0050  Accuracy: 98.470 %
# [epoch 115]  Loss: 0.0052  Accuracy: 98.498 %
# [epoch 116]  Loss: 0.0065  Accuracy: 98.152 %
# [epoch 117]  Loss: 0.0046  Accuracy: 98.626 %
# [epoch 118]  Loss: 0.0050  Accuracy: 98.494 %
# [epoch 119]  Loss: 0.0054  Accuracy: 98.386 %
# [epoch 120]  Loss: 0.0051  Accuracy: 98.484 %
# [epoch 121]  Loss: 0.0050  Accuracy: 98.430 %
# [epoch 122]  Loss: 0.0050  Accuracy: 98.522 %
# [epoch 123]  Loss: 0.0052  Accuracy: 98.440 %
# [epoch 124]  Loss: 0.0042  Accuracy: 98.698 %
# [epoch 125]  Loss: 0.0049  Accuracy: 98.630 %
# [epoch 126]  Loss: 0.0061  Accuracy: 98.344 %
# [epoch 127]  Loss: 0.0043  Accuracy: 98.780 %
# [epoch 128]  Loss: 0.0044  Accuracy: 98.716 %
# [epoch 129]  Loss: 0.0057  Accuracy: 98.484 %
# [epoch 130]  Loss: 0.0040  Accuracy: 98.800 %
# [epoch 131]  Loss: 0.0046  Accuracy: 98.648 %
# [epoch 132]  Loss: 0.0045  Accuracy: 98.710 %
# [epoch 133]  Loss: 0.0081  Accuracy: 97.920 %
# [epoch 134]  Loss: 0.0035  Accuracy: 98.992 %
# [epoch 135]  Loss: 0.0041  Accuracy: 98.776 %
# [epoch 136]  Loss: 0.0045  Accuracy: 98.688 %
# [epoch 137]  Loss: 0.0038  Accuracy: 98.836 %
# [epoch 138]  Loss: 0.0045  Accuracy: 98.650 %
# [epoch 139]  Loss: 0.0049  Accuracy: 98.590 %
# [epoch 140]  Loss: 0.0036  Accuracy: 98.914 %
# [epoch 141]  Loss: 0.0053  Accuracy: 98.552 %
# [epoch 142]  Loss: 0.0045  Accuracy: 98.716 %
# [epoch 143]  Loss: 0.0038  Accuracy: 98.924 %
# [epoch 144]  Loss: 0.0039  Accuracy: 98.844 %
# [epoch 145]  Loss: 0.0036  Accuracy: 98.942 %
# [epoch 146]  Loss: 0.0038  Accuracy: 98.856 %
# [epoch 147]  Loss: 0.0048  Accuracy: 98.644 %
# [epoch 148]  Loss: 0.0037  Accuracy: 98.920 %
# [epoch 149]  Loss: 0.0046  Accuracy: 98.736 %
# [epoch 150]  Loss: 0.0039  Accuracy: 98.884 %
# [epoch 151]  Loss: 0.0037  Accuracy: 98.908 %
# [epoch 152]  Loss: 0.0048  Accuracy: 98.624 %
# [epoch 153]  Loss: 0.0032  Accuracy: 99.072 %
# [epoch 154]  Loss: 0.0038  Accuracy: 98.974 %
# [epoch 155]  Loss: 0.0036  Accuracy: 98.960 %
# [epoch 156]  Loss: 0.0047  Accuracy: 98.684 %
# [epoch 157]  Loss: 0.0033  Accuracy: 99.048 %
# [epoch 158]  Loss: 0.0039  Accuracy: 98.882 %
# [epoch 159]  Loss: 0.0033  Accuracy: 98.982 %
# [epoch 160]  Loss: 0.0036  Accuracy: 98.904 %
# [epoch 161]  Loss: 0.0050  Accuracy: 98.770 %
# [epoch 162]  Loss: 0.0029  Accuracy: 99.174 %
# [epoch 163]  Loss: 0.0041  Accuracy: 98.874 %
# [epoch 164]  Loss: 0.0042  Accuracy: 98.872 %
# [epoch 165]  Loss: 0.0032  Accuracy: 99.070 %
# [epoch 166]  Loss: 0.0034  Accuracy: 99.030 %
# [epoch 167]  Loss: 0.0034  Accuracy: 98.982 %
# [epoch 168]  Loss: 0.0036  Accuracy: 98.984 %
# [epoch 169]  Loss: 0.0029  Accuracy: 99.154 %
# [epoch 170]  Loss: 0.0058  Accuracy: 98.544 %
# [epoch 171]  Loss: 0.0065  Accuracy: 98.316 %
# [epoch 172]  Loss: 0.0030  Accuracy: 99.172 %
# [epoch 173]  Loss: 0.0034  Accuracy: 99.070 %
# [epoch 174]  Loss: 0.0037  Accuracy: 98.926 %
# [epoch 175]  Loss: 0.0038  Accuracy: 98.980 %
# [epoch 176]  Loss: 0.0032  Accuracy: 99.128 %
# [epoch 177]  Loss: 0.0027  Accuracy: 99.200 %
# [epoch 178]  Loss: 0.0066  Accuracy: 98.374 %
# [epoch 179]  Loss: 0.0033  Accuracy: 99.088 %
# [epoch 180]  Loss: 0.0028  Accuracy: 99.220 %
# [epoch 181]  Loss: 0.0031  Accuracy: 99.112 %
# [epoch 182]  Loss: 0.0029  Accuracy: 99.184 %
# [epoch 183]  Loss: 0.0033  Accuracy: 99.106 %
# [epoch 184]  Loss: 0.0040  Accuracy: 98.878 %
# [epoch 185]  Loss: 0.0028  Accuracy: 99.192 %
# [epoch 186]  Loss: 0.0031  Accuracy: 99.138 %
# [epoch 187]  Loss: 0.0040  Accuracy: 98.920 %
# [epoch 188]  Loss: 0.0027  Accuracy: 99.246 %
# [epoch 189]  Loss: 0.0038  Accuracy: 98.968 %
# [epoch 190]  Loss: 0.0031  Accuracy: 99.146 %
# [epoch 191]  Loss: 0.0031  Accuracy: 99.106 %
# [epoch 192]  Loss: 0.0037  Accuracy: 98.974 %
# [epoch 193]  Loss: 0.0031  Accuracy: 99.136 %
# [epoch 194]  Loss: 0.0029  Accuracy: 99.174 %
# [epoch 195]  Loss: 0.0028  Accuracy: 99.148 %
# [epoch 196]  Loss: 0.0033  Accuracy: 99.132 %
# [epoch 197]  Loss: 0.0107  Accuracy: 98.030 %
# [epoch 198]  Loss: 0.0051  Accuracy: 98.570 %
# [epoch 199]  Loss: 0.0021  Accuracy: 99.400 %
# Finished Training! Training process cost 2860.212906 sec

# %%
# show the loss
plt.plot(np.arange(len(train_loss)), train_loss)

# %%
# show the accuracy
plt.plot(np.arange(len(train_accu)), train_accu)

# %%
# close the TensorBoard output stream
writer.close()

# %%
#ALL THE CODE IN THIS CELL ARE WRITE BY MY SELF#
# Start testing : set net to train model
correct = 0
total = 0

# deactivate the autograd engine
with torch.no_grad():
    
    # do testing iteration
    #for data in testingloader:
        
        # get the input and its label
        #images, labels = data
        #images, labels = images.to(device), labels.to(device)
    for i, (inputs, labels) in enumerate(trainingloader, 0):
        
        # get the input and its label
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # forward step
        outputs = net(inputs)
        
        # compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total = total + labels.size(0)
        correct = correct + (predicted == labels).sum().item()

# Finish Testing
result_testing_accuracy = correct / total * 100.0
print('The accuracy of the network is %.3f %%' % result_testing_accuracy)
# Out:
# The accuracy of the network is 99.110 %

# %%
print('[Configuration]')
print('learning rate = %3f' % learning_rate )
print('batch size = %d' % batch_size )
print('epoch = %d' % epoch )
print('')
print('[Expirement Result]')
print('training time = %3f sec' % result_training_time )
print('training accuracy = %.3f %%' %result_training_accuracy )
print('testing accuracy =  %.3f %%' % (100.0 * correct / total))
# Out:
# [Configuration]
# learning rate = 0.001000
# batch size = 200
# epoch = 199
#
# [Expirement Result]
# training time = 2860.212906 sec
# training accuracy = 99.400 %
# testing accuracy =  99.110 %

# %% [markdown]
# <b>click <a href='../Main.ipynb'>here</a> to return to Main.ipynb
