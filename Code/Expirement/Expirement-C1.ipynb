# %% [markdown]
# # 18COC102 -  Advanced Artificial Intelligence Systems - Coursework

# %% [markdown]
# <hr>
# <p style='color:red'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Experiment C1</p>
# <hr>

# %%
# %pylab
# %matplotlib inline
# %load_ext watermark
# %watermark -v -p numpy,torch,torchvision
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# CPython 3.6.7
# IPython 7.2.0
#
# numpy 1.15.4
# torch 0.4.1
# torchvision 0.2.1

# %%
# import all dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import time
import os
from tensorboardX import SummaryWriter

# %%
# some of line are refer source[1]
# network (VGG16) : this network reduce some convolution cores in oder to improve speed
class VGG16(nn.Module):
    
    def __init__(self):
        
        super(VGG16,self).__init__()
        self.conv1 = nn.Conv2d(3,64,3,padding=1)
        self.conv2 = nn.Conv2d(64,64,3,padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu1 = nn.ReLU()

        self.conv3 = nn.Conv2d(64,128,3,padding=1)
        self.conv4 = nn.Conv2d(128, 128, 3,padding=1)
        self.pool2 = nn.MaxPool2d(2, 2, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.relu2 = nn.ReLU()

        self.conv5 = nn.Conv2d(128,128, 3,padding=1)
        self.conv6 = nn.Conv2d(128, 128, 3,padding=1)
        self.conv7 = nn.Conv2d(128, 128, 1,padding=1)
        self.pool3 = nn.MaxPool2d(2, 2, padding=1)
        self.bn3 = nn.BatchNorm2d(128)
        self.relu3 = nn.ReLU()

        self.conv8 = nn.Conv2d(128, 256, 3,padding=1)
        self.conv9 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv10 = nn.Conv2d(256, 256, 1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2, padding=1)
        self.bn4 = nn.BatchNorm2d(256)
        self.relu4 = nn.ReLU()

        self.conv11 = nn.Conv2d(256, 512, 3, padding=1)
        self.conv12 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv13 = nn.Conv2d(512, 512, 1, padding=1)
        self.pool5 = nn.MaxPool2d(2, 2, padding=1)
        self.bn5 = nn.BatchNorm2d(512)
        self.relu5 = nn.ReLU()

        self.fc14 = nn.Linear(512*4*4,1024)
        self.drop1 = nn.Dropout2d()
        self.fc15 = nn.Linear(1024,1024)
        self.drop2 = nn.Dropout2d()
        self.fc16 = nn.Linear(1024,10)
        
    def forward(self,x):
        
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.pool1(x)
        x = self.bn1(x)
        x = self.relu1(x)


        x = self.conv3(x)
        x = self.conv4(x)
        x = self.pool2(x)
        x = self.bn2(x)
        x = self.relu2(x)

        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.pool3(x)
        x = self.bn3(x)
        x = self.relu3(x)

        x = self.conv8(x)
        x = self.conv9(x)
        x = self.conv10(x)
        x = self.pool4(x)
        x = self.bn4(x)
        x = self.relu4(x)

        x = self.conv11(x)
        x = self.conv12(x)
        x = self.conv13(x)
        x = self.pool5(x)
        x = self.bn5(x)
        x = self.relu5(x)

        x = x.view(-1,512*4*4)
        x = F.relu(self.fc14(x))
        x = self.drop1(x)
        x = F.relu(self.fc15(x))
        x = self.drop2(x)
        x = self.fc16(x)

        return x

#end of source [1]
#source [1] https://juejin.im/entry/5bf51d35e51d454049668d57

# %%
# parameters
learning_rate=0.001
batch_size=200
epoch=200
workers=2

# %%
# set GPU 
device = torch.device("cuda:0")
# set Netwrok
net = VGG16()
net = net.to(device)
# set optimizer
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
# set loss function
loss = nn.CrossEntropyLoss()

# %%
# dataloader refer source [2]

# load training dataset
trainingset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, 
                                           transform=transforms.ToTensor())

trainingloader = torch.utils.data.DataLoader(trainingset, batch_size=batch_size,shuffle=True, 
                                             num_workers=workers)
# load testing dataset
testingset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transforms.ToTensor())

testingloader = torch.utils.data.DataLoader(testingset, batch_size=batch_size,
                                         shuffle=False, num_workers=workers)

#end of source [2]
#source [2] https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#ALL THE CODE IN THIS CELL ARE WRITE BY MY SELF#
# Start training : set net to train model
net.train()

# make two arrays for saving matplotlib data
train_loss = []
train_accu = []
accuracy = 0

# get TersorBoard writer object
writer = SummaryWriter(log_dir='Training')

# Training process
timestart = time.time()
for epoch in range(0,epoch):
    
    # initialize loss,total,correct
    loss_value = 0.0
    total = 0
    correct = 0
    accuracy = 0
    
    # do iteration (total number of training images / batch size) times
    for i, (inputs, labels) in enumerate(trainingloader, 0):
        
        # get the input and its label
        inputs = inputs.to(device)
        labels = labels.to(device)

        # make gradients to 0
        optimizer.zero_grad()

        # forward step
        outputs = net(inputs)
        
        # compute the loss
        l = loss(outputs, labels)
        
        # backward step
        l.backward()
        
        # optimize step
        optimizer.step()

        # compute loss
        loss_value += l.item()
        
        # save to array in oder to output loss image at the end
        train_loss.append(l.item())
        
        # write to tensorboard file
        writer.add_scalars('/GroupC/Loss', {'C1': l.item()}, epoch)

        
        # compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total = total + labels.size(0)
        correct = correct + (predicted == labels).sum().item()
        accuracy = correct / total * 100.0
        
        # save to array in oder to output accuracy image at the end
        train_accu.append(accuracy)
        
        # write to tensorboard file
        writer.add_scalars('/GroupC/Accuracy', {'C1': accuracy}, epoch)
        

    loss_epoch = loss_value / (500000/batch_size)
    # output the result of this epoch 
    print('[epoch %d]  Loss: %.4f  Accuracy: %.3f %%' %(epoch, loss_epoch , accuracy))

    
# Finish Training
result_training_accuracy = accuracy
result_training_time = (time.time()-timestart)
print('Finished Training! Training process cost %3f sec' %result_training_time)
# Out:
# [epoch 0]  Loss: 0.1831  Accuracy: 27.492 %
# [epoch 1]  Loss: 0.1467  Accuracy: 42.718 %
# [epoch 2]  Loss: 0.1230  Accuracy: 54.444 %
# [epoch 3]  Loss: 0.1064  Accuracy: 62.252 %
# [epoch 4]  Loss: 0.0954  Accuracy: 66.436 %
# [epoch 5]  Loss: 0.0871  Accuracy: 69.578 %
# [epoch 6]  Loss: 0.0792  Accuracy: 72.448 %
# [epoch 7]  Loss: 0.0738  Accuracy: 74.746 %
# [epoch 8]  Loss: 0.0685  Accuracy: 76.910 %
# [epoch 9]  Loss: 0.0637  Accuracy: 78.462 %
# [epoch 10]  Loss: 0.0604  Accuracy: 79.774 %
# [epoch 11]  Loss: 0.0564  Accuracy: 81.242 %
# [epoch 12]  Loss: 0.0531  Accuracy: 82.252 %
# [epoch 13]  Loss: 0.0499  Accuracy: 83.448 %
# [epoch 14]  Loss: 0.0469  Accuracy: 84.510 %
# [epoch 15]  Loss: 0.0448  Accuracy: 85.200 %
# [epoch 16]  Loss: 0.0425  Accuracy: 85.912 %
# [epoch 17]  Loss: 0.0401  Accuracy: 86.664 %
# [epoch 18]  Loss: 0.0382  Accuracy: 87.354 %
# [epoch 19]  Loss: 0.0362  Accuracy: 87.900 %
# [epoch 20]  Loss: 0.0347  Accuracy: 88.710 %
# [epoch 21]  Loss: 0.0320  Accuracy: 89.434 %
# [epoch 22]  Loss: 0.0317  Accuracy: 89.554 %
# [epoch 23]  Loss: 0.0297  Accuracy: 90.234 %
# [epoch 24]  Loss: 0.0282  Accuracy: 90.768 %
# [epoch 25]  Loss: 0.0266  Accuracy: 91.308 %
# [epoch 26]  Loss: 0.0256  Accuracy: 91.672 %
# [epoch 27]  Loss: 0.0237  Accuracy: 92.270 %
# [epoch 28]  Loss: 0.0235  Accuracy: 92.472 %
# [epoch 29]  Loss: 0.0227  Accuracy: 92.636 %
# [epoch 30]  Loss: 0.0213  Accuracy: 93.032 %
# [epoch 31]  Loss: 0.0198  Accuracy: 93.708 %
# [epoch 32]  Loss: 0.0193  Accuracy: 93.840 %
# [epoch 33]  Loss: 0.0186  Accuracy: 94.052 %
# [epoch 34]  Loss: 0.0177  Accuracy: 94.260 %
# [epoch 35]  Loss: 0.0171  Accuracy: 94.526 %
# [epoch 36]  Loss: 0.0168  Accuracy: 94.586 %
# [epoch 37]  Loss: 0.0157  Accuracy: 95.088 %
# [epoch 38]  Loss: 0.0151  Accuracy: 95.268 %
# [epoch 39]  Loss: 0.0149  Accuracy: 95.256 %
# [epoch 40]  Loss: 0.0135  Accuracy: 95.658 %
# [epoch 41]  Loss: 0.0132  Accuracy: 95.750 %
# [epoch 42]  Loss: 0.0130  Accuracy: 95.898 %
# [epoch 43]  Loss: 0.0122  Accuracy: 96.176 %
# [epoch 44]  Loss: 0.0119  Accuracy: 96.236 %
# [epoch 45]  Loss: 0.0117  Accuracy: 96.438 %
# [epoch 46]  Loss: 0.0113  Accuracy: 96.516 %
# [epoch 47]  Loss: 0.0102  Accuracy: 96.758 %
# [epoch 48]  Loss: 0.0104  Accuracy: 96.698 %
# [epoch 49]  Loss: 0.0101  Accuracy: 96.846 %
# [epoch 50]  Loss: 0.0096  Accuracy: 96.976 %
# [epoch 51]  Loss: 0.0108  Accuracy: 96.672 %
# [epoch 52]  Loss: 0.0096  Accuracy: 96.992 %
# [epoch 53]  Loss: 0.0087  Accuracy: 97.306 %
# [epoch 54]  Loss: 0.0086  Accuracy: 97.328 %
# [epoch 55]  Loss: 0.0089  Accuracy: 97.290 %
# [epoch 56]  Loss: 0.0087  Accuracy: 97.330 %
# [epoch 57]  Loss: 0.0077  Accuracy: 97.614 %
# [epoch 58]  Loss: 0.0085  Accuracy: 97.328 %
# [epoch 59]  Loss: 0.0077  Accuracy: 97.620 %
# [epoch 60]  Loss: 0.0080  Accuracy: 97.510 %
# [epoch 61]  Loss: 0.0070  Accuracy: 97.798 %
# [epoch 62]  Loss: 0.0068  Accuracy: 97.816 %
# [epoch 63]  Loss: 0.0072  Accuracy: 97.808 %
# [epoch 64]  Loss: 0.0065  Accuracy: 97.960 %
# [epoch 65]  Loss: 0.0066  Accuracy: 97.952 %
# [epoch 66]  Loss: 0.0068  Accuracy: 97.976 %
# [epoch 67]  Loss: 0.0063  Accuracy: 98.076 %
# [epoch 68]  Loss: 0.0067  Accuracy: 98.020 %
# [epoch 69]  Loss: 0.0067  Accuracy: 98.010 %
# [epoch 70]  Loss: 0.0061  Accuracy: 98.084 %
# [epoch 71]  Loss: 0.0063  Accuracy: 98.104 %
# [epoch 72]  Loss: 0.0063  Accuracy: 98.024 %
# [epoch 73]  Loss: 0.0056  Accuracy: 98.264 %
# [epoch 74]  Loss: 0.0055  Accuracy: 98.322 %
# [epoch 75]  Loss: 0.0068  Accuracy: 97.904 %
# [epoch 76]  Loss: 0.0057  Accuracy: 98.322 %
# [epoch 77]  Loss: 0.0050  Accuracy: 98.432 %
# [epoch 78]  Loss: 0.0051  Accuracy: 98.396 %
# [epoch 79]  Loss: 0.0054  Accuracy: 98.312 %
# [epoch 80]  Loss: 0.0056  Accuracy: 98.252 %
# [epoch 81]  Loss: 0.0051  Accuracy: 98.394 %
# [epoch 82]  Loss: 0.0047  Accuracy: 98.544 %
# [epoch 83]  Loss: 0.0052  Accuracy: 98.354 %
# [epoch 84]  Loss: 0.0055  Accuracy: 98.404 %
# [epoch 85]  Loss: 0.0049  Accuracy: 98.492 %
# [epoch 86]  Loss: 0.0039  Accuracy: 98.772 %
# [epoch 87]  Loss: 0.0044  Accuracy: 98.634 %
# [epoch 88]  Loss: 0.0050  Accuracy: 98.446 %
# [epoch 89]  Loss: 0.0050  Accuracy: 98.456 %
# [epoch 90]  Loss: 0.0041  Accuracy: 98.742 %
# [epoch 91]  Loss: 0.0047  Accuracy: 98.570 %
# [epoch 92]  Loss: 0.0042  Accuracy: 98.686 %
# [epoch 93]  Loss: 0.0041  Accuracy: 98.698 %
# [epoch 94]  Loss: 0.0041  Accuracy: 98.708 %
# [epoch 95]  Loss: 0.0040  Accuracy: 98.816 %
# [epoch 96]  Loss: 0.0038  Accuracy: 98.846 %
# [epoch 97]  Loss: 0.0046  Accuracy: 98.642 %
# [epoch 98]  Loss: 0.0040  Accuracy: 98.730 %
# [epoch 99]  Loss: 0.0041  Accuracy: 98.686 %
# [epoch 100]  Loss: 0.0045  Accuracy: 98.608 %
# [epoch 101]  Loss: 0.0040  Accuracy: 98.724 %
# [epoch 102]  Loss: 0.0042  Accuracy: 98.754 %
# [epoch 103]  Loss: 0.0035  Accuracy: 98.902 %
# [epoch 104]  Loss: 0.0033  Accuracy: 98.942 %
# [epoch 105]  Loss: 0.0039  Accuracy: 98.752 %
# [epoch 106]  Loss: 0.0034  Accuracy: 98.932 %
# [epoch 107]  Loss: 0.0033  Accuracy: 99.006 %
# [epoch 108]  Loss: 0.0036  Accuracy: 98.896 %
# [epoch 109]  Loss: 0.0029  Accuracy: 99.040 %
# [epoch 110]  Loss: 0.0034  Accuracy: 99.008 %
# [epoch 111]  Loss: 0.0045  Accuracy: 98.668 %
# [epoch 112]  Loss: 0.0033  Accuracy: 98.954 %
# [epoch 113]  Loss: 0.0040  Accuracy: 98.840 %
# [epoch 114]  Loss: 0.0033  Accuracy: 99.046 %
# [epoch 115]  Loss: 0.0039  Accuracy: 98.838 %
# [epoch 116]  Loss: 0.0032  Accuracy: 98.970 %
# [epoch 117]  Loss: 0.0037  Accuracy: 98.864 %
# [epoch 118]  Loss: 0.0035  Accuracy: 98.942 %
# [epoch 119]  Loss: 0.0029  Accuracy: 99.124 %
# [epoch 120]  Loss: 0.0028  Accuracy: 99.120 %
# [epoch 121]  Loss: 0.0036  Accuracy: 98.874 %
# [epoch 122]  Loss: 0.0033  Accuracy: 99.002 %
# [epoch 123]  Loss: 0.0034  Accuracy: 98.954 %
# [epoch 124]  Loss: 0.0027  Accuracy: 99.124 %
# [epoch 125]  Loss: 0.0035  Accuracy: 98.898 %
# [epoch 126]  Loss: 0.0031  Accuracy: 99.002 %
# [epoch 127]  Loss: 0.0028  Accuracy: 99.140 %
# [epoch 128]  Loss: 0.0026  Accuracy: 99.202 %
# [epoch 129]  Loss: 0.0025  Accuracy: 99.260 %
# [epoch 130]  Loss: 0.0035  Accuracy: 98.922 %
# [epoch 131]  Loss: 0.0029  Accuracy: 99.130 %
# [epoch 132]  Loss: 0.0027  Accuracy: 99.228 %
# [epoch 133]  Loss: 0.0031  Accuracy: 99.062 %
# [epoch 134]  Loss: 0.0027  Accuracy: 99.138 %
# [epoch 135]  Loss: 0.0026  Accuracy: 99.166 %
# [epoch 136]  Loss: 0.0024  Accuracy: 99.232 %
# [epoch 137]  Loss: 0.0037  Accuracy: 98.856 %
# [epoch 138]  Loss: 0.0028  Accuracy: 99.188 %
# [epoch 139]  Loss: 0.0024  Accuracy: 99.304 %
# [epoch 140]  Loss: 0.0031  Accuracy: 98.990 %
# [epoch 141]  Loss: 0.0037  Accuracy: 98.878 %
# [epoch 142]  Loss: 0.0021  Accuracy: 99.382 %
# [epoch 143]  Loss: 0.0029  Accuracy: 99.020 %
# [epoch 144]  Loss: 0.0026  Accuracy: 99.238 %
# [epoch 145]  Loss: 0.0032  Accuracy: 99.078 %
# [epoch 146]  Loss: 0.0020  Accuracy: 99.426 %
# [epoch 147]  Loss: 0.0029  Accuracy: 99.160 %
# [epoch 148]  Loss: 0.0028  Accuracy: 99.124 %
# [epoch 149]  Loss: 0.0021  Accuracy: 99.348 %
# [epoch 150]  Loss: 0.0027  Accuracy: 99.164 %
# [epoch 151]  Loss: 0.0024  Accuracy: 99.266 %
# [epoch 152]  Loss: 0.0026  Accuracy: 99.232 %
# [epoch 153]  Loss: 0.0027  Accuracy: 99.190 %
# [epoch 154]  Loss: 0.0025  Accuracy: 99.292 %
# [epoch 155]  Loss: 0.0025  Accuracy: 99.252 %
# [epoch 156]  Loss: 0.0029  Accuracy: 99.168 %
# [epoch 157]  Loss: 0.0023  Accuracy: 99.290 %
# [epoch 158]  Loss: 0.0024  Accuracy: 99.260 %
# [epoch 159]  Loss: 0.0023  Accuracy: 99.262 %
# [epoch 160]  Loss: 0.0021  Accuracy: 99.354 %
# [epoch 161]  Loss: 0.0023  Accuracy: 99.268 %
# [epoch 162]  Loss: 0.0029  Accuracy: 99.130 %
# [epoch 163]  Loss: 0.0020  Accuracy: 99.348 %
# [epoch 164]  Loss: 0.0030  Accuracy: 99.072 %
# [epoch 165]  Loss: 0.0021  Accuracy: 99.394 %
# [epoch 166]  Loss: 0.0022  Accuracy: 99.350 %
# [epoch 167]  Loss: 0.0021  Accuracy: 99.350 %
# [epoch 168]  Loss: 0.0025  Accuracy: 99.272 %
# [epoch 169]  Loss: 0.0021  Accuracy: 99.384 %
# [epoch 170]  Loss: 0.0016  Accuracy: 99.512 %
# [epoch 171]  Loss: 0.0028  Accuracy: 99.202 %
# [epoch 172]  Loss: 0.0018  Accuracy: 99.464 %
# [epoch 173]  Loss: 0.0020  Accuracy: 99.406 %
# [epoch 174]  Loss: 0.0024  Accuracy: 99.296 %
# [epoch 175]  Loss: 0.0022  Accuracy: 99.318 %
# [epoch 176]  Loss: 0.0019  Accuracy: 99.418 %
# [epoch 177]  Loss: 0.0026  Accuracy: 99.252 %
# [epoch 178]  Loss: 0.0021  Accuracy: 99.362 %
# [epoch 179]  Loss: 0.0018  Accuracy: 99.424 %
# [epoch 180]  Loss: 0.0023  Accuracy: 99.302 %
# [epoch 181]  Loss: 0.0024  Accuracy: 99.254 %
# [epoch 182]  Loss: 0.0018  Accuracy: 99.458 %
# [epoch 183]  Loss: 0.0027  Accuracy: 99.248 %
# [epoch 184]  Loss: 0.0019  Accuracy: 99.406 %
# [epoch 185]  Loss: 0.0023  Accuracy: 99.270 %
# [epoch 186]  Loss: 0.0014  Accuracy: 99.556 %
# [epoch 187]  Loss: 0.0021  Accuracy: 99.374 %
# [epoch 188]  Loss: 0.0020  Accuracy: 99.432 %
# [epoch 189]  Loss: 0.0018  Accuracy: 99.442 %
# [epoch 190]  Loss: 0.0020  Accuracy: 99.412 %
# [epoch 191]  Loss: 0.0026  Accuracy: 99.258 %
# [epoch 192]  Loss: 0.0020  Accuracy: 99.390 %
# [epoch 193]  Loss: 0.0017  Accuracy: 99.448 %
# [epoch 194]  Loss: 0.0024  Accuracy: 99.270 %
# [epoch 195]  Loss: 0.0021  Accuracy: 99.364 %
# [epoch 196]  Loss: 0.0017  Accuracy: 99.494 %
# [epoch 197]  Loss: 0.0023  Accuracy: 99.350 %
# [epoch 198]  Loss: 0.0016  Accuracy: 99.520 %
# [epoch 199]  Loss: 0.0021  Accuracy: 99.378 %
# Finished Training! Training process cost 5745.132426 sec

# %%
# show the loss
plt.plot(np.arange(len(train_loss)), train_loss)

# %%
# show the accuracy
plt.plot(np.arange(len(train_accu)), train_accu)

# %%
# close the TensorBoard output stream
writer.close()

# %%
#ALL THE CODE IN THIS CELL ARE WRITE BY MY SELF#
# Start testing : set net to train model
correct = 0
total = 0

# deactivate the autograd engine
with torch.no_grad():
    
    # do testing iteration
    #for data in testingloader:
        
        # get the input and its label
        #images, labels = data
        #images, labels = images.to(device), labels.to(device)
    for i, (inputs, labels) in enumerate(trainingloader, 0):
        
        # get the input and its label
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # forward step
        outputs = net(inputs)
        
        # compute accuracy
        _, predicted = torch.max(outputs.data, 1)
        total = total + labels.size(0)
        correct = correct + (predicted == labels).sum().item()

# Finish Testing
result_testing_accuracy = correct / total * 100.0
print('The accuracy of the network is %.3f %%' % result_testing_accuracy)
# Out:
# The accuracy of the network is 99.652 %

# %%
print('[Configuration]')
print('learning rate = %3f' % learning_rate )
print('batch size = %d' % batch_size )
print('epoch = %d' % epoch )
print('')
print('[Expirement Result]')
print('training time = %3f sec' % result_training_time )
print('training accuracy = %.3f %%' %result_training_accuracy )
print('testing accuracy =  %.3f %%' % (100.0 * correct / total))
# Out:
# [Configuration]
# learning rate = 0.001000
# batch size = 200
# epoch = 199
#
# [Expirement Result]
# training time = 5745.132426 sec
# training accuracy = 99.378 %
# testing accuracy =  99.652 %

# %% [markdown]
# <b>click <a href='../Main.ipynb'>here</a> to return to Main.ipynb
